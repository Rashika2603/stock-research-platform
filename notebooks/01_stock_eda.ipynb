# %% [markdown]
# # Stock Market Research Platform
#
# ## Exploratory Data Analysis (EDA)
#
# ### Author
# Rashika Agarwal
#
# ### Objective
#
# The objective of this notebook is to perform exploratory data analysis on historical stock market data collected using Yahoo Finance.
#
# This analysis aims to:
#
# - Understand stock price behavior over time
# - Explore the statistical properties of the data
# - Identify missing values and potential data quality issues
# - Generate insights using visualizations
# - Prepare the dataset for feature engineering and machine learning

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## 2. Load Apple Stock Dataset

# %%
aapl = pd.read_csv(
    "../data/raw/AAPL.csv",
    index_col="Date",
    parse_dates=True
)

aapl.head()
# Out:
#                 Close       High        Low       Open     Volume
# Date
# 2020-01-02  72.333885  72.394093  71.091191  71.344062  135480400
# 2020-01-03  71.630661  72.389280  71.406689  71.563228  146322800
# 2020-01-06  72.201431  72.239965  70.503569  70.754036  118387200
# 2020-01-07  71.861839  72.466322  71.642681  72.211041  108872000
# 2020-01-08  73.017853  73.318893  71.565636  71.565636  132079200

# %% [markdown]
# ## 3. Dataset Information

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1628 entries, 2020-01-02 to 2026-06-25
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1628 non-null   float64
#  1   High    1628 non-null   float64
#  2   Low     1628 non-null   float64
#  3   Open    1628 non-null   float64
#  4   Volume  1628 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 76.3 KB

# %% [markdown]
# ## 4. Statistical Summary

# %%
aapl.describe()
# Out:
#              Close         High          Low         Open        Volume
# count  1628.000000  1628.000000  1628.000000  1628.000000  1.628000e+03
# mean    172.603195   174.390870   170.683961   172.462315  8.188450e+07
# std      55.737273    56.179436    55.327491    55.738475  5.049625e+07
# min      54.163704    55.160702    51.324800    55.059313  1.791060e+07
# 25%     134.593174   136.302051   132.415615   134.507080  4.890652e+07
# 50%     168.251762   169.689272   166.719160   167.915708  6.793505e+07
# 75%     213.077183   215.308501   211.005907   213.064585  9.690462e+07
# max     315.200012   317.399994   309.649994   314.179993  4.265100e+08

# %% [markdown]
# ## 5. Missing Value Analysis

# %%
aapl.isnull().sum()
# Out:
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %% [markdown]
# ## 6. Dataset Dimensions

# %%
aapl.shape
# Out:
# (1628, 5)

# %% [markdown]
# ## 7. Column Names

# %%
aapl.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %% [markdown]
# ## 8. Date Index

# %%
aapl.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2026-06-11', '2026-06-12', '2026-06-15', '2026-06-16',
#                '2026-06-17', '2026-06-18', '2026-06-22', '2026-06-23',
#                '2026-06-24', '2026-06-25'],
#               dtype='datetime64[ns]', name='Date', length=1628, freq=None)
